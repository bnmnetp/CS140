# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://millbr02:@localhost/employees
# Out:
# 'Connected: millbr02@employees'

# %% [markdown]
# # Nested Queries

# %% [markdown]
# It is perfectly legal to embed one select statement inside another.  In fact a select statement can be used anywhere a table with a name can be used.   Also, queries that return just a single value can be used in a comparison expression.
#
# Selects can be embeded in:
#
# * The from clause   --- Must have an alias
# * The where clause
# * A having clause
#
#
#
# First lets look at a couple of dumb examples.  There is no good reason to use nested queries for this as we can do it easier with a simple join.

# %%
# %%sql
#
# select emp_no
# from (select emp_no, first_name, last_name from dept_emp natural join employees) as foo
# limit 10;
# Out:
# 10 rows affected.
# [(10001,),
#  (10002,),
#  (10003,),
#  (10004,),
#  (10005,),
#  (10006,),
#  (10007,),
#  (10008,),
#  (10009,),
#  (10010,)]

# %%
# %%sql
#
# select first_name, last_name
# from employees
# where emp_no in (select emp_no from salaries where salary < 39000)
# order by last_name, first_name
# Out:
# 21 rows affected.
# [('Denny', 'Assaf'),
#  ('Olivera', 'Baek'),
#  ('Vishu', 'Biran'),
#  ('Younwoo', 'Champarnaud'),
#  ('Bernd', 'Copas'),
#  ('Shahaf', 'England'),
#  ('Zhiguo', 'Kobuchi'),
#  ('Chuanyi', 'Kuhnemann'),
#  ('Mechthild', 'Langford'),
#  ('Pascal', 'Lueh'),
#  ('Matt', 'Munch'),
#  ('Yurij', 'Narwekar'),
#  ('Sachar', 'Nicolson'),
#  ('Nahum', 'Nitsche'),
#  ('Yagil', 'Perri'),
#  ('Monique', 'Reinhard'),
#  ('Gill', 'Rohrbach'),
#  ('Jacqueline', 'Syang'),
#  ('Fumiya', 'Unno'),
#  ('Christfried', 'Werthner'),
#  ('Toshimitsu', 'Yavatkar')]

# %% [markdown]
# Of course this is a bad way to do it...

# %%
# %%sql
# select first_name, last_name
# from employees natural join (select emp_no from salaries where salary < 39000 ) as foo
# order by
# Out:
# 22 rows affected.
# [('Monique', 'Reinhard'),
#  ('Yurij', 'Narwekar'),
#  ('Jacqueline', 'Syang'),
#  ('Fumiya', 'Unno'),
#  ('Fumiya', 'Unno'),
#  ('Vishu', 'Biran'),
#  ('Bernd', 'Copas'),
#  ('Mechthild', 'Langford'),
#  ('Yagil', 'Perri'),
#  ('Shahaf', 'England'),
#  ('Denny', 'Assaf'),
#  ('Pascal', 'Lueh'),
#  ('Olivera', 'Baek'),
#  ('Gill', 'Rohrbach'),
#  ('Matt', 'Munch'),
#  ('Chuanyi', 'Kuhnemann'),
#  ('Younwoo', 'Champarnaud'),
#  ('Sachar', 'Nicolson'),
#  ('Christfried', 'Werthner'),
#  ('Nahum', 'Nitsche'),
#  ('Zhiguo', 'Kobuchi'),
#  ('Toshimitsu', 'Yavatkar')]

# %%
# %%sql
#
# select first_name, last_name
# from employees natural join salaries
# where salary < 39000
# order by last_name, first_name
# Out:
# 22 rows affected.
# [('Denny', 'Assaf'),
#  ('Olivera', 'Baek'),
#  ('Vishu', 'Biran'),
#  ('Younwoo', 'Champarnaud'),
#  ('Bernd', 'Copas'),
#  ('Shahaf', 'England'),
#  ('Zhiguo', 'Kobuchi'),
#  ('Chuanyi', 'Kuhnemann'),
#  ('Mechthild', 'Langford'),
#  ('Pascal', 'Lueh'),
#  ('Matt', 'Munch'),
#  ('Yurij', 'Narwekar'),
#  ('Sachar', 'Nicolson'),
#  ('Nahum', 'Nitsche'),
#  ('Yagil', 'Perri'),
#  ('Monique', 'Reinhard'),
#  ('Gill', 'Rohrbach'),
#  ('Jacqueline', 'Syang'),
#  ('Fumiya', 'Unno'),
#  ('Fumiya', 'Unno'),
#  ('Christfried', 'Werthner'),
#  ('Toshimitsu', 'Yavatkar')]

# %% [markdown]
# ## Revisiting the relational algebra extend
#
# * Add a column that corresponds to decade
# * Add a constant column

# %%
# %%sql
#
# select date_part('year', hire_date)::integer, hire_date, birth_date from employees limit 10;
# Out:
# 10 rows affected.
# [(1986, datetime.date(1986, 6, 26), datetime.date(1953, 9, 2)),
#  (1985, datetime.date(1985, 11, 21), datetime.date(1964, 6, 2)),
#  (1986, datetime.date(1986, 8, 28), datetime.date(1959, 12, 3)),
#  (1986, datetime.date(1986, 12, 1), datetime.date(1954, 5, 1)),
#  (1989, datetime.date(1989, 9, 12), datetime.date(1955, 1, 21)),
#  (1989, datetime.date(1989, 6, 2), datetime.date(1953, 4, 20)),
#  (1989, datetime.date(1989, 2, 10), datetime.date(1957, 5, 23)),
#  (1994, datetime.date(1994, 9, 15), datetime.date(1958, 2, 19)),
#  (1985, datetime.date(1985, 2, 18), datetime.date(1952, 4, 19)),
#  (1989, datetime.date(1989, 8, 24), datetime.date(1963, 6, 1))]

# %%
# %%sql
#
# select date_part('year', hire_date)::integer/10*10 decade, hire_date, birth_date from employees limit 10;
# Out:
# 10 rows affected.
# [(1980, datetime.date(1986, 6, 26), datetime.date(1953, 9, 2)),
#  (1980, datetime.date(1985, 11, 21), datetime.date(1964, 6, 2)),
#  (1980, datetime.date(1986, 8, 28), datetime.date(1959, 12, 3)),
#  (1980, datetime.date(1986, 12, 1), datetime.date(1954, 5, 1)),
#  (1980, datetime.date(1989, 9, 12), datetime.date(1955, 1, 21)),
#  (1980, datetime.date(1989, 6, 2), datetime.date(1953, 4, 20)),
#  (1980, datetime.date(1989, 2, 10), datetime.date(1957, 5, 23)),
#  (1990, datetime.date(1994, 9, 15), datetime.date(1958, 2, 19)),
#  (1980, datetime.date(1985, 2, 18), datetime.date(1952, 4, 19)),
#  (1980, datetime.date(1989, 8, 24), datetime.date(1963, 6, 1))]

# %%
# %sql select 'hello' greeting, birth_date, hire_date from employees limit 10;
# Out:
# 10 rows affected.
# [('hello', datetime.date(1953, 9, 2), datetime.date(1986, 6, 26)),
#  ('hello', datetime.date(1964, 6, 2), datetime.date(1985, 11, 21)),
#  ('hello', datetime.date(1959, 12, 3), datetime.date(1986, 8, 28)),
#  ('hello', datetime.date(1954, 5, 1), datetime.date(1986, 12, 1)),
#  ('hello', datetime.date(1955, 1, 21), datetime.date(1989, 9, 12)),
#  ('hello', datetime.date(1953, 4, 20), datetime.date(1989, 6, 2)),
#  ('hello', datetime.date(1957, 5, 23), datetime.date(1989, 2, 10)),
#  ('hello', datetime.date(1958, 2, 19), datetime.date(1994, 9, 15)),
#  ('hello', datetime.date(1952, 4, 19), datetime.date(1985, 2, 18)),
#  ('hello', datetime.date(1963, 6, 1), datetime.date(1989, 8, 24))]

# %% [markdown]
# * How old were you when you were hired?
# * What is the average age at the time of hire?

# %%
# %%sql
#
# select (hire_date - birth_date)/365 from employees limit 10;
# Out:
# 10 rows affected.
# [(32,), (21,), (26,), (32,), (34,), (36,), (31,), (36,), (32,), (26,)]

# %%
# %%sql
#
# select avg(hire_age) from (select (hire_date - birth_date)/365 hire_age from employees limit 10) T
# Out:
# 1 rows affected.
# [(Decimal('30.6000000000000000'),)]

# %% [markdown]
# ### Who has held the most titles?

# %%
# %%sql
#
# select emp_no, count(*)
# from titles
# group by emp_no
# order by count(*) desc
# limit 10;
# Out:
# (psycopg2.ProgrammingError) aggregate function calls cannot be nested
# LINE 1: select emp_no, max(count(*))
#                            ^
#  [SQL: 'select emp_no, max(count(*))\nfrom titles\ngroup by emp_no\norder by count(*) desc\nlimit 10;']

# %% [markdown]
# OK, this gives us the emp_no's of the employees with the most.  How can we use this to find the names?   A nested query!

# %%
# %%sql
# select first_name, last_name, hire_date
# from employees natural join (select emp_no, count(*)
#     from titles
#     group by emp_no
#     order by count(*) desc
#     limit 10) as foo
# Out:
# 10 rows affected.
# [('Fun', 'Varman', datetime.date(1985, 2, 24)),
#  ('Nahid', 'Chepyzhov', datetime.date(1990, 11, 11)),
#  ('Basil', 'Ishibashi', datetime.date(1985, 5, 17)),
#  ('Bodh', 'Ranta', datetime.date(1988, 3, 12)),
#  ('Gil', 'Peroz', datetime.date(1991, 9, 2)),
#  ('Krisda', 'Krogh', datetime.date(1985, 9, 11)),
#  ('Kwee', 'Schusler', datetime.date(1986, 2, 26)),
#  ('Sumant', 'Peac', datetime.date(1985, 2, 18)),
#  ('Remzi', 'Cappello', datetime.date(1986, 5, 7)),
#  ('Mariangiola', 'Gulla', datetime.date(1987, 5, 24))]

# %% [markdown]
# We can even include columns from the nested query in our final result as follows:

# %%
# %%sql
#
# select first_name, last_name, hire_date, tcount
# from employees natural join (select emp_no, count(*) tcount
#     from titles
#     group by emp_no
#     order by count(*) desc
#     limit 10) as foo
# order by hire_date;
# Out:
# 10 rows affected.
# [('Sumant', 'Peac', datetime.date(1985, 2, 18), 3),
#  ('Fun', 'Varman', datetime.date(1985, 2, 24), 3),
#  ('Basil', 'Ishibashi', datetime.date(1985, 5, 17), 3),
#  ('Krisda', 'Krogh', datetime.date(1985, 9, 11), 3),
#  ('Kwee', 'Schusler', datetime.date(1986, 2, 26), 3),
#  ('Remzi', 'Cappello', datetime.date(1986, 5, 7), 3),
#  ('Mariangiola', 'Gulla', datetime.date(1987, 5, 24), 3),
#  ('Bodh', 'Ranta', datetime.date(1988, 3, 12), 3),
#  ('Nahid', 'Chepyzhov', datetime.date(1990, 11, 11), 3),
#  ('Gil', 'Peroz', datetime.date(1991, 9, 2), 3)]

# %% [markdown]
# Find all of the emplyees having max count.

# %%
# %%sql
#
# select first_name, last_name, hire_date, tcount
# from employees natural join (select emp_no, count(*) tcount
#     from titles
#     group by emp_no
#     having count(*) >= (select max(count) from (select emp_no, count(*) from titles group by emp_no) as bar)
#     order by count(*) desc
#     ) as foo
# order by hire_date;
# Out:
# 3014 rows affected.
# [('Yakkov', 'Impagliazzo', datetime.date(1985, 2, 2), 3),
#  ('Taiji', 'Kemmerer', datetime.date(1985, 2, 2), 3),
#  ('Ayonca', 'Bruckman', datetime.date(1985, 2, 3), 3),
#  ('Shih', 'Auria', datetime.date(1985, 2, 4), 3),
#  ('Martine', 'Plotkin', datetime.date(1985, 2, 4), 3),
#  ('Panayotis', 'Thisen', datetime.date(1985, 2, 5), 3),
#  ('Shahab', 'Rotem', datetime.date(1985, 2, 5), 3),
#  ('Fumitaka', 'Akiyama', datetime.date(1985, 2, 5), 3),
#  ('Hilary', 'Snyers', datetime.date(1985, 2, 5), 3),
#  ('Tadahiro', 'Beeson', datetime.date(1985, 2, 6), 3),
#  ('Bartek', 'Bain', datetime.date(1985, 2, 6), 3),
#  ('Moni', 'Godskesen', datetime.date(1985, 2, 7), 3),
#  ('Sahrah', 'Roohalamini', datetime.date(1985, 2, 7), 3),
#  ('Nathalie', 'Pocchiola', datetime.date(1985, 2, 8), 3),
#  ('Gennadi', 'Plesums', datetime.date(1985, 2, 8), 3),
#  ('Nirmal', 'Khamsi', datetime.date(1985, 2, 8), 3),
#  ('Etsuo', 'Milicic', datetime.date(1985, 2, 8), 3),
#  ('Tsz', 'Hutter', datetime.date(1985, 2, 9), 3),
#  ('Along', 'Schaar', datetime.date(1985, 2, 9), 3),
#  ('Theron', 'Zirintsis', datetime.date(1985, 2, 9), 3),
#  ('Teruyuki', 'Ouhyoung', datetime.date(1985, 2, 9), 3),
#  ('Duro', 'Hiyoshi', datetime.date(1985, 2, 10), 3),
#  ('Baruch', 'Erdmenger', datetime.date(1985, 2, 10), 3),
#  ('Duri', 'Beutelspacher', datetime.date(1985, 2, 11), 3),
#  ('Duangkaew', 'Auyong', datetime.date(1985, 2, 11), 3),
#  ('Kamran', 'Szilard', datetime.date(1985, 2, 11), 3),
#  ('Luisa', 'Suwa', datetime.date(1985, 2, 12), 3),
#  ('Reuven', 'Oberman', datetime.date(1985, 2, 12), 3),
#  ('Huiqun', 'Thisen', datetime.date(1985, 2, 12), 3),
#  ('Shmuel', 'Perly', datetime.date(1985, 2, 12), 3),
#  ('Janche', 'Ghandeharizadeh', datetime.date(1985, 2, 13), 3),
#  ('Tadanori', 'Morrow', datetime.date(1985, 2, 13), 3),
#  ('Naraig', 'Wilharm', datetime.date(1985, 2, 13), 3),
#  ('Divine', 'Luit', datetime.date(1985, 2, 13), 3),
#  ('Kamran', 'Emden', datetime.date(1985, 2, 14), 3),
#  ('Younwoo', 'Benzmuller', datetime.date(1985, 2, 14), 3),
#  ('Tomofumi', 'Restivo', datetime.date(1985, 2, 14), 3),
#  ('Avishai', 'Quittner', datetime.date(1985, 2, 14), 3),
#  ('Jaana', 'Kornatzky', datetime.date(1985, 2, 14), 3),
#  ('Chirstian', 'Murillo', datetime.date(1985, 2, 15), 3),
#  ('Guangming', 'Staudhammer', datetime.date(1985, 2, 15), 3),
#  ('Tiina', 'Potthoff', datetime.date(1985, 2, 15), 3),
#  ('Sven', 'Bugaenko', datetime.date(1985, 2, 16), 3),
#  ('Tetsushi', 'Seghrouchni', datetime.date(1985, 2, 16), 3),
#  ('Irena', 'Dredge', datetime.date(1985, 2, 17), 3),
#  ('Petter', 'Mattern', datetime.date(1985, 2, 17), 3),
#  ('Arun', 'Hanratty', datetime.date(1985, 2, 17), 3),
#  ('Constantine', 'Lampe', datetime.date(1985, 2, 17), 3),
#  ('Hausi', 'Manders', datetime.date(1985, 2, 17), 3),
#  ('Anneke', 'Bennet', datetime.date(1985, 2, 17), 3),
#  ('Samphel', 'Berztiss', datetime.date(1985, 2, 18), 3),
#  ('Saniya', 'Candan', datetime.date(1985, 2, 18), 3),
#  ('Sumant', 'Peac', datetime.date(1985, 2, 18), 3),
#  ('Kwangyoen', 'Arlazarov', datetime.date(1985, 2, 18), 3),
#  ('Adam', 'Perry', datetime.date(1985, 2, 18), 3),
#  ('Remko', 'Fendler', datetime.date(1985, 2, 18), 3),
#  ('Sakthirel', 'Oberman', datetime.date(1985, 2, 18), 3),
#  ('Utpal', 'Jiang', datetime.date(1985, 2, 18), 3),
#  ('Weiye', 'Spieker', datetime.date(1985, 2, 18), 3),
#  ('Tristan', 'Marwedel', datetime.date(1985, 2, 19), 3),
#  ('Poornachandra', 'Templeman', datetime.date(1985, 2, 19), 3),
#  ('Patricio', 'Percebois', datetime.date(1985, 2, 20), 3),
#  ('Zhongwei', 'Lunt', datetime.date(1985, 2, 20), 3),
#  ('Indrajit', 'Benner', datetime.date(1985, 2, 20), 3),
#  ('Leszek', 'Moffat', datetime.date(1985, 2, 20), 3),
#  ('Mokhtar', 'Slaats', datetime.date(1985, 2, 21), 3),
#  ('Byong', 'Felcyn', datetime.date(1985, 2, 21), 3),
#  ('Oguz', 'Candan', datetime.date(1985, 2, 21), 3),
#  ('Krister', 'Ebeling', datetime.date(1985, 2, 21), 3),
#  ('Eldridge', 'Cheshire', datetime.date(1985, 2, 22), 3),
#  ('Kendra', 'Gurbaxani', datetime.date(1985, 2, 22), 3),
#  ('Martien', 'Encarnacion', datetime.date(1985, 2, 23), 3),
#  ('Roddy', 'Debuse', datetime.date(1985, 2, 23), 3),
#  ('Angel', 'Peek', datetime.date(1985, 2, 23), 3),
#  ('Dmitry', 'Honglei', datetime.date(1985, 2, 23), 3),
#  ('Gennady', 'Ariola', datetime.date(1985, 2, 23), 3),
#  ('Fun', 'Varman', datetime.date(1985, 2, 24), 3),
#  ('Cullen', 'Vieri', datetime.date(1985, 2, 24), 3),
#  ('Hauke', 'Pearson', datetime.date(1985, 2, 25), 3),
#  ('Arvind', 'Naudin', datetime.date(1985, 2, 25), 3),
#  ('Lunjin', 'Chenoweth', datetime.date(1985, 2, 25), 3),
#  ('Amalendu', 'Camarinopoulos', datetime.date(1985, 2, 26), 3),
#  ('Tonia', 'Burnard', datetime.date(1985, 2, 26), 3),
#  ('Volkmar', 'Piveteau', datetime.date(1985, 2, 26), 3),
#  ('Shawna', 'Moffat', datetime.date(1985, 2, 26), 3),
#  ('Leszek', 'Raoux', datetime.date(1985, 2, 27), 3),
#  ('Bodo', 'Angel', datetime.date(1985, 2, 27), 3),
#  ('Shaleah', 'Ventosa', datetime.date(1985, 2, 28), 3),
#  ('Takahito', 'Zweizig', datetime.date(1985, 3, 1), 3),
#  ('Yechiam', 'Baer', datetime.date(1985, 3, 1), 3),
#  ('Irene', 'Conti', datetime.date(1985, 3, 1), 3),
#  ('Fen', 'Maraist', datetime.date(1985, 3, 2), 3),
#  ('Sigeru', 'Aamodt', datetime.date(1985, 3, 2), 3),
#  ('Erzsebet', 'Varker', datetime.date(1985, 3, 4), 3),
#  ('Khaled', 'Bojadziev', datetime.date(1985, 3, 4), 3),
#  ('Mana', 'Viele', datetime.date(1985, 3, 4), 3),
#  ('Yonghoan', 'Broomell', datetime.date(1985, 3, 5), 3),
#  ('Nobuyoshi', 'Pouyioutas', datetime.date(1985, 3, 5), 3),
#  ('Sergi', 'Kinley', datetime.date(1985, 3, 5), 3),
#  ('Menkae', 'Strehl', datetime.date(1985, 3, 5), 3),
#  ('Renee', 'Brookman', datetime.date(1985, 3, 6), 3),
#  ('Arnould', 'Rusterholz', datetime.date(1985, 3, 7), 3),
#  ('Maris', 'Krybus', datetime.date(1985, 3, 8), 3),
#  ('Deniz', 'Baba', datetime.date(1985, 3, 9), 3),
#  ('Annemarie', 'Bresenham', datetime.date(1985, 3, 10), 3),
#  ('Guttorm', 'Bage', datetime.date(1985, 3, 11), 3),
#  ('Aria', 'Rodier', datetime.date(1985, 3, 12), 3),
#  ('Rafael', 'Figueira', datetime.date(1985, 3, 12), 3),
#  ('Yonghong', 'Gubsky', datetime.date(1985, 3, 12), 3),
#  ('Arve', 'Hemaspaandra', datetime.date(1985, 3, 15), 3),
#  ('Mart', 'Bierbaum', datetime.date(1985, 3, 15), 3),
#  ('Juyoung', 'Riesenhuber', datetime.date(1985, 3, 16), 3),
#  ('Anyuan', 'Byoun', datetime.date(1985, 3, 16), 3),
#  ('Radhakrishnan', 'Iisaka', datetime.date(1985, 3, 16), 3),
#  ('Godehard', 'Lally', datetime.date(1985, 3, 16), 3),
#  ('Jamaludin', 'Zumaque', datetime.date(1985, 3, 16), 3),
#  ('KayLiang', 'Litecky', datetime.date(1985, 3, 17), 3),
#  ('Serenella', 'Braunschweig', datetime.date(1985, 3, 17), 3),
#  ('Sivanarayana', 'Trumbly', datetime.date(1985, 3, 17), 3),
#  ('Sumali', 'Bressoud', datetime.date(1985, 3, 17), 3),
#  ('Debaprosad', 'Soicher', datetime.date(1985, 3, 18), 3),
#  ('Aemilian', 'Zeleznik', datetime.date(1985, 3, 19), 3),
#  ('Ziyad', 'Kermarrec', datetime.date(1985, 3, 19), 3),
#  ('Moni', 'Candan', datetime.date(1985, 3, 19), 3),
#  ('Mingzeng', 'Servi', datetime.date(1985, 3, 19), 3),
#  ('Jacqueline', 'Ibel', datetime.date(1985, 3, 20), 3),
#  ('Erez', 'Fontet', datetime.date(1985, 3, 20), 3),
#  ('Hausi', 'Aloisi', datetime.date(1985, 3, 20), 3),
#  ('Christophe', 'Baer', datetime.date(1985, 3, 20), 3),
#  ('Genevieve', 'Hettesheimer', datetime.date(1985, 3, 21), 3),
#  ('Ohad', 'Panwar', datetime.date(1985, 3, 21), 3),
#  ('Sariel', 'Badache', datetime.date(1985, 3, 21), 3),
#  ('Akhilish', 'Isaak', datetime.date(1985, 3, 21), 3),
#  ('Zita', 'Peng', datetime.date(1985, 3, 21), 3),
#  ('Deniz', 'Osgood', datetime.date(1985, 3, 22), 3),
#  ('Arumugam', 'Peek', datetime.date(1985, 3, 22), 3),
#  ('Fan', 'Pashtan', datetime.date(1985, 3, 22), 3),
#  ('Huei', 'Chartres', datetime.date(1985, 3, 23), 3),
#  ('Alejandro', 'Chelton', datetime.date(1985, 3, 23), 3),
#  ('Hugo', 'Schurmann', datetime.date(1985, 3, 24), 3),
#  ('Youssef', 'Candan', datetime.date(1985, 3, 24), 3),
#  ('Saddek', 'Crouzet', datetime.date(1985, 3, 25), 3),
#  ('Hisao', 'Rahier', datetime.date(1985, 3, 25), 3),
#  ('Shigenori', 'Guerreiro', datetime.date(1985, 3, 26), 3),
#  ('Danny', 'Iacovou', datetime.date(1985, 3, 26), 3),
#  ('Tomokazu', 'Bondorf', datetime.date(1985, 3, 26), 3),
#  ('Barton', 'Janetzko', datetime.date(1985, 3, 27), 3),
#  ('Wonhee', 'Ramsey', datetime.date(1985, 3, 27), 3),
#  ('Unal', 'Ramras', datetime.date(1985, 3, 27), 3),
#  ('Alassane', 'Roisin', datetime.date(1985, 3, 28), 3),
#  ('Maik', 'Perng', datetime.date(1985, 3, 29), 3),
#  ('Jaewon', 'Maksimenko', datetime.date(1985, 3, 29), 3),
#  ('Radhakrishnan', 'Socorro', datetime.date(1985, 3, 29), 3),
#  ('Lech', 'Aseltine', datetime.date(1985, 3, 29), 3),
#  ('Oddvar', 'Wendorf', datetime.date(1985, 3, 30), 3),
#  ('Moto', 'Luan', datetime.date(1985, 3, 30), 3),
#  ('Jingling', 'Zizka', datetime.date(1985, 3, 31), 3),
#  ('Isamu', 'Swiss', datetime.date(1985, 4, 1), 3),
#  ('Ronghao', 'Pintelas', datetime.date(1985, 4, 1), 3),
#  ('Shaowei', 'Vecchio', datetime.date(1985, 4, 1), 3),
#  ('Apostol', 'Janocha', datetime.date(1985, 4, 2), 3),
#  ('Martina', 'Lores', datetime.date(1985, 4, 2), 3),
#  ('Arno', 'Vesel', datetime.date(1985, 4, 2), 3),
#  ('Suvo', 'Plotkin', datetime.date(1985, 4, 3), 3),
#  ('Dinkar', 'Garigliano', datetime.date(1985, 4, 4), 3),
#  ('Lucian', 'Falby', datetime.date(1985, 4, 4), 3),
#  ('Martina', 'Sewelson', datetime.date(1985, 4, 4), 3),
#  ('Zorica', 'Mansanne', datetime.date(1985, 4, 5), 3),
#  ('Jaana', 'Staelin', datetime.date(1985, 4, 5), 3),
#  ('Katsuo', 'Kroha', datetime.date(1985, 4, 6), 3),
#  ('Nikolaos', 'Melichar', datetime.date(1985, 4, 6), 3),
#  ('Heng', 'Kalorkoti', datetime.date(1985, 4, 7), 3),
#  ('Sigeru', 'Lueh', datetime.date(1985, 4, 10), 3),
#  ('Stevo', 'Steenbeek', datetime.date(1985, 4, 10), 3),
#  ('Jagoda', 'Gill', datetime.date(1985, 4, 10), 3),
#  ('Lokesh', 'Hmelo', datetime.date(1985, 4, 11), 3),
#  ('Zeydy', 'Krybus', datetime.date(1985, 4, 11), 3),
#  ('Yinghua', 'Demian', datetime.date(1985, 4, 11), 3),
#  ('Ymte', 'Goodrum', datetime.date(1985, 4, 11), 3),
#  ('Taegyun', 'Ravishankar', datetime.date(1985, 4, 12), 3),
#  ('Suvo', 'Lodder', datetime.date(1985, 4, 12), 3),
#  ('Mototsugu', 'Raczkowsky', datetime.date(1985, 4, 13), 3),
#  ('Sachar', 'Lakshmanan', datetime.date(1985, 4, 14), 3),
#  ('Yunming', 'Bala', datetime.date(1985, 4, 14), 3),
#  ('Mabry', 'Georgakopoulos', datetime.date(1985, 4, 15), 3),
#  ('Zine', 'Begiun', datetime.date(1985, 4, 15), 3),
#  ('Rildo', 'Conti', datetime.date(1985, 4, 16), 3),
#  ('Neelam', 'Kenevan', datetime.date(1985, 4, 16), 3),
#  ('Jackson', 'Felcyn', datetime.date(1985, 4, 17), 3),
#  ('Evgueni', 'Dulay', datetime.date(1985, 4, 17), 3),
#  ('Jaber', 'Dredge', datetime.date(1985, 4, 17), 3),
#  ('Krister', 'Schlegelmilch', datetime.date(1985, 4, 17), 3),
#  ('Gladys', 'Ossenbruggen', datetime.date(1985, 4, 18), 3),
#  ('Shiv', 'Mitsuhashi', datetime.date(1985, 4, 18), 3),
#  ('Sadok', 'Wroclawski', datetime.date(1985, 4, 18), 3),
#  ('Ramzi', 'Jording', datetime.date(1985, 4, 18), 3),
#  ('Shaunak', 'Boissier', datetime.date(1985, 4, 18), 3),
#  ('Satoru', 'Khalil', datetime.date(1985, 4, 19), 3),
#  ('Demos', 'Eppinger', datetime.date(1985, 4, 21), 3),
#  ('Zhilian', 'Schauser', datetime.date(1985, 4, 21), 3),
#  ('Amalendu', 'Farrel', datetime.date(1985, 4, 22), 3),
#  ('Huei', 'Chappelet', datetime.date(1985, 4, 22), 3),
#  ('Billur', 'Mayerwieser', datetime.date(1985, 4, 22), 3),
#  ('Susanta', 'Rijckaert', datetime.date(1985, 4, 23), 3),
#  ('Duke', 'Thimonier', datetime.date(1985, 4, 24), 3),
#  ('Ramachenga', 'Ferretti', datetime.date(1985, 4, 25), 3),
#  ('Utz', 'Cannata', datetime.date(1985, 4, 25), 3),
#  ('George', 'Markovitch', datetime.date(1985, 4, 25), 3),
#  ('Zhaofang', 'Pulkowski', datetime.date(1985, 4, 25), 3),
#  ('Hilary', 'Ullian', datetime.date(1985, 4, 25), 3),
#  ('Mariusz', 'Bazzichi', datetime.date(1985, 4, 26), 3),
#  ('Pramod', 'Whitcomb', datetime.date(1985, 4, 26), 3),
#  ('Magy', 'Cronin', datetime.date(1985, 4, 27), 3),
#  ('Hironobu', 'Chappelet', datetime.date(1985, 4, 27), 3),
#  ('Christoper', 'Muniz', datetime.date(1985, 4, 27), 3),
#  ('Bezalel', 'Barinka', datetime.date(1985, 4, 28), 3),
#  ('Lubomir', 'Qiwen', datetime.date(1985, 4, 29), 3),
#  ('Aleksandar', 'Marquardt', datetime.date(1985, 4, 29), 3),
#  ('Erez', 'Poujol', datetime.date(1985, 4, 29), 3),
#  ('Sanjai', 'Kitsuregawa', datetime.date(1985, 4, 29), 3),
#  ('Leandro', 'Brookman', datetime.date(1985, 4, 29), 3),
#  ('Aloke', 'Argence', datetime.date(1985, 4, 30), 3),
#  ('Doohun', 'Lienhardt', datetime.date(1985, 5, 1), 3),
#  ('Xiong', 'Noriega', datetime.date(1985, 5, 1), 3),
#  ('Toshimi', 'Frolund', datetime.date(1985, 5, 1), 3),
#  ('Zhenbing', 'Decaestecker', datetime.date(1985, 5, 1), 3),
#  ('Heeju', 'Armand', datetime.date(1985, 5, 1), 3),
#  ('Shahaf', 'Pulkowski', datetime.date(1985, 5, 2), 3),
#  ('Beshir', 'Mattern', datetime.date(1985, 5, 3), 3),
#  ('Visit', 'Nittel', datetime.date(1985, 5, 3), 3),
#  ('Kazuhito', 'Heiserman', datetime.date(1985, 5, 3), 3),
#  ('Ingmar', 'Landherr', datetime.date(1985, 5, 4), 3),
#  ('Juyoung', 'Merel', datetime.date(1985, 5, 4), 3),
#  ('Junichi', 'Grabner', datetime.date(1985, 5, 5), 3),
#  ('Florian', 'Francisci', datetime.date(1985, 5, 5), 3),
#  ('Kristina', 'Melichar', datetime.date(1985, 5, 6), 3),
#  ('Kinh', 'Pettey', datetime.date(1985, 5, 6), 3),
#  ('Kazuhide', 'Luke', datetime.date(1985, 5, 8), 3),
#  ('Lokesh', 'Whitcomb', datetime.date(1985, 5, 9), 3),
#  ('Spyrose', 'Ramsay', datetime.date(1985, 5, 9), 3),
#  ('Gretta', 'Bale', datetime.date(1985, 5, 9), 3),
#  ('Rafail', 'Nanard', datetime.date(1985, 5, 9), 3),
#  ('Jouni', 'McClurg', datetime.date(1985, 5, 10), 3),
#  ('Fan', 'Roohalamini', datetime.date(1985, 5, 10), 3),
#  ('Adil', 'Litecky', datetime.date(1985, 5, 10), 3),
#  ('Ipke', 'Uludag', datetime.date(1985, 5, 11), 3),
#  ('Indrajit', 'Weedman', datetime.date(1985, 5, 11), 3),
#  ('Shushma', 'Gargeya', datetime.date(1985, 5, 12), 3),
#  ('Zhaofang', 'Antonisse', datetime.date(1985, 5, 12), 3),
#  ('Nishit', 'Gerlach', datetime.date(1985, 5, 12), 3),
#  ('Sachio', 'Radwan', datetime.date(1985, 5, 12), 3),
#  ('Luise', 'Flowers', datetime.date(1985, 5, 13), 3),
#  ('Yishay', 'Rebaine', datetime.date(1985, 5, 13), 3),
#  ('Ayonca', 'Burnard', datetime.date(1985, 5, 13), 3),
#  ('Bojan', 'Delaune', datetime.date(1985, 5, 13), 3),
#  ('Karlis', 'Gide', datetime.date(1985, 5, 13), 3),
#  ('Noritoshi', 'Maliniak', datetime.date(1985, 5, 14), 3),
#  ('Djenana', 'Jording', datetime.date(1985, 5, 15), 3),
#  ('Jiann', 'Angelov', datetime.date(1985, 5, 16), 3),
#  ('Youssef', 'Jording', datetime.date(1985, 5, 16), 3),
#  ('Chaosheng', 'Lampe', datetime.date(1985, 5, 17), 3),
#  ('Kwangyoen', 'Hartvigsen', datetime.date(1985, 5, 17), 3),
#  ('Limsoon', 'Zuberek', datetime.date(1985, 5, 17), 3),
#  ('Basil', 'Ishibashi', datetime.date(1985, 5, 17), 3),
#  ('Keiichiro', 'Nastansky', datetime.date(1985, 5, 18), 3),
#  ('Boriana', 'Lally', datetime.date(1985, 5, 18), 3),
#  ('Kellyn', 'Farris', datetime.date(1985, 5, 19), 3),
#  ('Sailaja', 'McAlpine', datetime.date(1985, 5, 19), 3),
#  ('Mitsuyuki', 'Kalafatis', datetime.date(1985, 5, 20), 3),
#  ('Seshu', 'Kambil', datetime.date(1985, 5, 20), 3),
#  ('Jamaludin', 'Suri', datetime.date(1985, 5, 21), 3),
#  ('Srinidhi', 'Couchot', datetime.date(1985, 5, 22), 3),
#  ('Katsuo', 'Rothe', datetime.date(1985, 5, 22), 3),
#  ('Frederique', 'Berstel', datetime.date(1985, 5, 23), 3),
#  ('Mabo', 'Ruemmler', datetime.date(1985, 5, 23), 3),
#  ('Clyde', 'Gide', datetime.date(1985, 5, 23), 3),
#  ('Sahrah', 'Munke', datetime.date(1985, 5, 23), 3),
#  ('Moto', 'Emmart', datetime.date(1985, 5, 24), 3),
#  ('Ingemar', 'Wendorf', datetime.date(1985, 5, 24), 3),
#  ('Xiong', 'Yeung', datetime.date(1985, 5, 24), 3),
#  ('Mads', 'Argence', datetime.date(1985, 5, 24), 3),
#  ('Serenella', 'Rabehasaina', datetime.date(1985, 5, 25), 3),
#  ('Masato', 'Baranowski', datetime.date(1985, 5, 25), 3),
#  ('Gladys', 'Dayang', datetime.date(1985, 5, 26), 3),
#  ('Yinlin', 'Gist', datetime.date(1985, 5, 26), 3),
#  ('Gererd', 'Narlikar', datetime.date(1985, 5, 26), 3),
#  ('Krassimir', 'Schrooten', datetime.date(1985, 5, 26), 3),
#  ('Pascal', 'Hambrick', datetime.date(1985, 5, 26), 3),
#  ('Susumu', 'Navazio', datetime.date(1985, 5, 27), 3),
#  ('Arun', 'Orlowska', datetime.date(1985, 5, 27), 3),
#  ('Yechiam', 'Ramsak', datetime.date(1985, 5, 27), 3),
#  ('Xiaoqiu', 'Buchter', datetime.date(1985, 5, 28), 3),
#  ('Jinpo', 'Woycyznski', datetime.date(1985, 5, 28), 3),
#  ('Trygve', 'Vieth', datetime.date(1985, 5, 29), 3),
#  ('Weiye', 'Kuzuoka', datetime.date(1985, 5, 30), 3),
#  ('Kristina', 'Peng', datetime.date(1985, 5, 30), 3),
#  ('Ebru', 'Botman', datetime.date(1985, 5, 30), 3),
#  ('Xiaoshan', 'Cesareni', datetime.date(1985, 5, 30), 3),
#  ('Munir', 'Lenart', datetime.date(1985, 5, 31), 3),
#  ('Gao', 'Haddadi', datetime.date(1985, 5, 31), 3),
#  ('Thodoros', 'Steenbeek', datetime.date(1985, 6, 1), 3),
#  ('Gro', 'Fandrianto', datetime.date(1985, 6, 1), 3),
#  ('Srinidhi', 'Hofting', datetime.date(1985, 6, 2), 3),
#  ('Kiyomitsu', 'Oxenboll', datetime.date(1985, 6, 2), 3),
#  ('Zhanqiu', 'Ginneken', datetime.date(1985, 6, 3), 3),
#  ('Pascal', 'Angot', datetime.date(1985, 6, 3), 3),
#  ('Xiahua', 'Compeau', datetime.date(1985, 6, 3), 3),
#  ('Marek', 'Lanzelotte', datetime.date(1985, 6, 4), 3),
#  ('Pradeep', 'Plessier', datetime.date(1985, 6, 4), 3),
#  ('Sorina', 'Perng', datetime.date(1985, 6, 4), 3),
#  ('Jungsoon', 'Zschoche', datetime.date(1985, 6, 5), 3),
#  ('Marin', 'Spinelli', datetime.date(1985, 6, 6), 3),
#  ('Pranay', 'Ertl', datetime.date(1985, 6, 6), 3),
#  ('Roddy', 'Matzat', datetime.date(1985, 6, 6), 3),
#  ('JoAnna', 'Simmel', datetime.date(1985, 6, 7), 3),
#  ('Henk', 'Unni', datetime.date(1985, 6, 7), 3),
#  ('Rimon', 'Thombley', datetime.date(1985, 6, 7), 3),
#  ('Baocai', 'Broomell', datetime.date(1985, 6, 8), 3),
#  ('Maren', 'Vilarrasa', datetime.date(1985, 6, 9), 3),
#  ('Zhaofang', 'Bernardeschi', datetime.date(1985, 6, 9), 3),
#  ('Marjo', 'Jansen', datetime.date(1985, 6, 10), 3),
#  ('Conor', 'Kambil', datetime.date(1985, 6, 10), 3),
#  ('Haldon', 'Denos', datetime.date(1985, 6, 11), 3),
#  ('Rildo', 'Merlo', datetime.date(1985, 6, 11), 3),
#  ('Guther', 'Verhaegen', datetime.date(1985, 6, 11), 3),
#  ('Hideo', 'Ratnakar', datetime.date(1985, 6, 13), 3),
#  ('Uzi', 'Ferretti', datetime.date(1985, 6, 15), 3),
#  ('Abdelkader', 'Hatcliff', datetime.date(1985, 6, 15), 3),
#  ('Otilia', 'Krichel', datetime.date(1985, 6, 15), 3),
#  ('Yinlin', 'Coney', datetime.date(1985, 6, 16), 3),
#  ('Steve', 'Kavraki', datetime.date(1985, 6, 17), 3),
#  ('Lalit', 'Hmelo', datetime.date(1985, 6, 17), 3),
#  ('Masaru', 'Rothe', datetime.date(1985, 6, 18), 3),
#  ('Akemi', 'Ponthieu', datetime.date(1985, 6, 19), 3),
#  ('Jingling', 'Orlowski', datetime.date(1985, 6, 19), 3),
#  ('Masami', 'Kaelbling', datetime.date(1985, 6, 20), 3),
#  ('Richard', 'Diderrich', datetime.date(1985, 6, 20), 3),
#  ('Hidde', 'Bauknecht', datetime.date(1985, 6, 20), 3),
#  ('Yonghoan', 'Collette', datetime.date(1985, 6, 20), 3),
#  ('Wanqing', 'Rande', datetime.date(1985, 6, 20), 3),
#  ('Bojan', 'Snyers', datetime.date(1985, 6, 21), 3),
#  ('Kristof', 'Schaap', datetime.date(1985, 6, 21), 3),
#  ('Maha', 'Heping', datetime.date(1985, 6, 22), 3),
#  ('Nobuyoshi', 'Koshino', datetime.date(1985, 6, 22), 3),
#  ('Kristen', 'Mandell', datetime.date(1985, 6, 22), 3),
#  ('Abdelwaheb', 'Pepe', datetime.date(1985, 6, 23), 3),
#  ('Khalid', 'Kushner', datetime.date(1985, 6, 24), 3),
#  ('Sreenivas', 'Wixon', datetime.date(1985, 6, 25), 3),
#  ('Abdelwaheb', 'England', datetime.date(1985, 6, 25), 3),
#  ('Shietung', 'Gecsel', datetime.date(1985, 6, 25), 3),
#  ('Kwan', 'Merey', datetime.date(1985, 6, 25), 3),
#  ('Mart', 'Heijenga', datetime.date(1985, 6, 25), 3),
#  ('Leucio', 'Sluis', datetime.date(1985, 6, 25), 3),
#  ('Wanqing', 'Shigei', datetime.date(1985, 6, 26), 3),
#  ('Pintsang', 'Lubachevsky', datetime.date(1985, 6, 26), 3),
#  ('Takushi', 'Wissmann', datetime.date(1985, 6, 27), 3),
#  ('Genta', 'Auria', datetime.date(1985, 6, 27), 3),
#  ('Danil', 'Benner', datetime.date(1985, 6, 27), 3),
#  ('Tokuyasu', 'Beausoleil', datetime.date(1985, 6, 27), 3),
#  ('Candido', 'Cappello', datetime.date(1985, 6, 28), 3),
#  ('Prasadram', 'Flowers', datetime.date(1985, 6, 29), 3),
#  ('Jianhua', 'Wielonsky', datetime.date(1985, 6, 30), 3),
#  ('Shirish', 'Verhaegen', datetime.date(1985, 6, 30), 3),
#  ('Henk', 'Szemeredi', datetime.date(1985, 6, 30), 3),
#  ('Kwan', 'Gils', datetime.date(1985, 7, 1), 3),
#  ('Baoqiu', 'Socorro', datetime.date(1985, 7, 3), 3),
#  ('Abdelkader', 'Peac', datetime.date(1985, 7, 3), 3),
#  ('Lech', 'Cannard', datetime.date(1985, 7, 4), 3),
#  ('Snehasis', 'Kusakabe', datetime.date(1985, 7, 4), 3),
#  ('Kiyomitsu', 'Gronowski', datetime.date(1985, 7, 5), 3),
#  ('Marie', 'Orsini', datetime.date(1985, 7, 5), 3),
#  ('Dines', 'Sundgren', datetime.date(1985, 7, 6), 3),
#  ('Atreye', 'Plump', datetime.date(1985, 7, 6), 3),
#  ('Marco', 'Zultner', datetime.date(1985, 7, 6), 3),
#  ('Lobel', 'Begiun', datetime.date(1985, 7, 6), 3),
#  ('Chuanti', 'Rosenbaum', datetime.date(1985, 7, 6), 3),
#  ('Shounak', 'Wursthorn', datetime.date(1985, 7, 7), 3),
#  ('Ramzi', 'Hashii', datetime.date(1985, 7, 7), 3),
#  ('Arno', 'Demizu', datetime.date(1985, 7, 7), 3),
#  ('Xiaobin', 'Ginesta', datetime.date(1985, 7, 8), 3),
#  ('Fuqing', 'Gluchowski', datetime.date(1985, 7, 8), 3),
#  ('Genta', 'Liedekerke', datetime.date(1985, 7, 8), 3),
#  ('Steen', 'Gonthier', datetime.date(1985, 7, 9), 3),
#  ('Shridhar', 'Penz', datetime.date(1985, 7, 9), 3),
#  ('Theirry', 'Joslin', datetime.date(1985, 7, 9), 3),
#  ('Pramod', 'Szilard', datetime.date(1985, 7, 10), 3),
#  ('Heekeun', 'Pesch', datetime.date(1985, 7, 10), 3),
#  ('Sarita', 'Koyama', datetime.date(1985, 7, 11), 3),
#  ('Masali', 'Randt', datetime.date(1985, 7, 11), 3),
#  ('Malu', 'Ashish', datetime.date(1985, 7, 12), 3),
#  ('Rance', 'Schicker', datetime.date(1985, 7, 13), 3),
#  ('Sailaja', 'Sambasivam', datetime.date(1985, 7, 14), 3),
#  ('Fumiyo', 'Norsworthy', datetime.date(1985, 7, 14), 3),
#  ('Shem', 'Vasanthakumar', datetime.date(1985, 7, 15), 3),
#  ('Jeane', 'Kinley', datetime.date(1985, 7, 16), 3),
#  ('Becky', 'Penttonen', datetime.date(1985, 7, 16), 3),
#  ('Moti', 'Ciolek', datetime.date(1985, 7, 17), 3),
#  ('Yaghout', 'Ramsay', datetime.date(1985, 7, 17), 3),
#  ('Zhensheng', 'Heystek', datetime.date(1985, 7, 17), 3),
#  ('Sariel', 'Camarinopoulos', datetime.date(1985, 7, 18), 3),
#  ('Boutros', 'Kirkerud', datetime.date(1985, 7, 18), 3),
#  ('Kasturi', 'Delgrange', datetime.date(1985, 7, 19), 3),
#  ('Atreyi', 'Navazio', datetime.date(1985, 7, 19), 3),
#  ('Seshu', 'Olivero', datetime.date(1985, 7, 19), 3),
#  ('Jacopo', 'Impagliazzo', datetime.date(1985, 7, 20), 3),
#  ('Hilary', 'Osgood', datetime.date(1985, 7, 20), 3),
#  ('Margareta', 'Turnbull', datetime.date(1985, 7, 20), 3),
#  ('Steen', 'Ramamoorthy', datetime.date(1985, 7, 21), 3),
#  ('Zito', 'Moehrke', datetime.date(1985, 7, 21), 3),
#  ('Kensei', 'Strooper', datetime.date(1985, 7, 21), 3),
#  ('Houman', 'Roccetti', datetime.date(1985, 7, 22), 3),
#  ('Munenori', 'Benveniste', datetime.date(1985, 7, 22), 3),
#  ('Greger', 'Pero', datetime.date(1985, 7, 23), 3),
#  ('Ute', 'Zuberek', datetime.date(1985, 7, 23), 3),
#  ('Wojceich', 'Lambe', datetime.date(1985, 7, 23), 3),
#  ('Poorav', 'Picht', datetime.date(1985, 7, 24), 3),
#  ('Alois', 'Denis', datetime.date(1985, 7, 24), 3),
#  ('Lidong', 'Pillow', datetime.date(1985, 7, 24), 3),
#  ('Filipp', 'Sommen', datetime.date(1985, 7, 26), 3),
#  ('Alair', 'Passafiume', datetime.date(1985, 7, 27), 3),
#  ('Arne', 'Cooke', datetime.date(1985, 7, 27), 3),
#  ('Hyuckchul', 'Boissier', datetime.date(1985, 7, 27), 3),
#  ('Frederique', 'Penz', datetime.date(1985, 7, 27), 3),
#  ('Hatim', 'Montresor', datetime.date(1985, 7, 28), 3),
#  ('Xiong', 'Tasistro', datetime.date(1985, 7, 28), 3),
#  ('Breannda', 'Basagni', datetime.date(1985, 7, 28), 3),
#  ('Chinho', 'Bottner', datetime.date(1985, 7, 29), 3),
#  ('Licheng', 'Liedekerke', datetime.date(1985, 7, 29), 3),
#  ('Qunsheng', 'Oskamp', datetime.date(1985, 7, 29), 3),
#  ('Yongdong', 'Nicolson', datetime.date(1985, 7, 29), 3),
#  ('Venkatesan', 'Trystram', datetime.date(1985, 7, 30), 3),
#  ('Rafael', 'Pettis', datetime.date(1985, 7, 30), 3),
#  ('Gadiel', 'Terwilliger', datetime.date(1985, 7, 30), 3),
#  ('Yoshimitsu', 'Standera', datetime.date(1985, 7, 30), 3),
#  ('Renny', 'Siepmann', datetime.date(1985, 7, 30), 3),
#  ('Fumiko', 'Magliocco', datetime.date(1985, 7, 31), 3),
#  ('Zito', 'Luiz', datetime.date(1985, 7, 31), 3),
#  ('Moni', 'Verspoor', datetime.date(1985, 8, 1), 3),
#  ('Xudong', 'Liesche', datetime.date(1985, 8, 1), 3),
#  ('Kazuyasu', 'Jumpertz', datetime.date(1985, 8, 2), 3),
#  ('Brewster', 'Matzov', datetime.date(1985, 8, 2), 3),
#  ('Munehiro', 'Vakili', datetime.date(1985, 8, 2), 3),
#  ('Kazuhiko', 'Suomi', datetime.date(1985, 8, 2), 3),
#  ('Theirry', 'Sridhar', datetime.date(1985, 8, 2), 3),
#  ('Kristine', 'Onuegbe', datetime.date(1985, 8, 3), 3),
#  ('Mohammad', 'Suppi', datetime.date(1985, 8, 3), 3),
#  ('Val', 'Malinowski', datetime.date(1985, 8, 4), 3),
#  ('Mokhtar', 'Kropf', datetime.date(1985, 8, 5), 3),
#  ('Kristian', 'Ranta', datetime.date(1985, 8, 5), 3),
#  ('Jolita', 'Gihr', datetime.date(1985, 8, 6), 3),
#  ('Lakshmi', 'Nivat', datetime.date(1985, 8, 7), 3),
#  ('Barry', 'Ramsey', datetime.date(1985, 8, 8), 3),
#  ('Tran', 'Zielinski', datetime.date(1985, 8, 8), 3),
#  ('Leif', 'Junet', datetime.date(1985, 8, 8), 3),
#  ('Mizuhito', 'Poujol', datetime.date(1985, 8, 9), 3),
#  ('Sudharsan', 'Worfolk', datetime.date(1985, 8, 10), 3),
#  ('Przemyslawa', 'Encarnacion', datetime.date(1985, 8, 10), 3),
#  ('Manton', 'Warwick', datetime.date(1985, 8, 10), 3),
#  ('Tommaso', 'Kalloufi', datetime.date(1985, 8, 10), 3),
#  ('Yagil', 'Lanteri', datetime.date(1985, 8, 10), 3),
#  ('Adib', 'Schmittgen', datetime.date(1985, 8, 10), 3),
#  ('Moss', 'Zumaque', datetime.date(1985, 8, 11), 3),
#  ('Tua', 'Kisuki', datetime.date(1985, 8, 11), 3),
#  ('Zeydy', 'Schiper', datetime.date(1985, 8, 12), 3),
#  ('Padma', 'Ashish', datetime.date(1985, 8, 12), 3),
#  ('Kristinn', 'Rahimi', datetime.date(1985, 8, 12), 3),
#  ('Kazuhito', 'Rattan', datetime.date(1985, 8, 13), 3),
#  ('Bernd', 'Fujisaki', datetime.date(1985, 8, 13), 3),
#  ('Yinghua', 'Merro', datetime.date(1985, 8, 14), 3),
#  ('Howell', 'Matzen', datetime.date(1985, 8, 15), 3),
#  ('Duro', 'Wossner', datetime.date(1985, 8, 15), 3),
#  ('Heejo', 'Waterhouse', datetime.date(1985, 8, 15), 3),
#  ('Utpal', 'Zschoche', datetime.date(1985, 8, 16), 3),
#  ('Sachio', 'Denny', datetime.date(1985, 8, 16), 3),
#  ('Kazuhira', 'Lalonde', datetime.date(1985, 8, 16), 3),
#  ('Renee', 'Terkki', datetime.date(1985, 8, 17), 3),
#  ('Fei', 'Gubsky', datetime.date(1985, 8, 17), 3),
#  ('Saeko', 'Vesna', datetime.date(1985, 8, 19), 3),
#  ('Along', 'Erie', datetime.date(1985, 8, 19), 3),
#  ('Harngdar', 'Bazzichi', datetime.date(1985, 8, 19), 3),
#  ('Karlis', 'Holburn', datetime.date(1985, 8, 20), 3),
#  ('Ronghao', 'Perry', datetime.date(1985, 8, 20), 3),
#  ('Ewing', 'Chinal', datetime.date(1985, 8, 20), 3),
#  ('Kendra', 'Waterhouse', datetime.date(1985, 8, 21), 3),
#  ('Shirish', 'Couchot', datetime.date(1985, 8, 21), 3),
#  ('Dulce', 'Facello', datetime.date(1985, 8, 22), 3),
#  ('Mansur', 'Kamble', datetime.date(1985, 8, 22), 3),
#  ('Kellie', 'Erez', datetime.date(1985, 8, 22), 3),
#  ('Leucio', 'Kaiserswerth', datetime.date(1985, 8, 23), 3),
#  ('Moon', 'Uhrik', datetime.date(1985, 8, 23), 3),
#  ('Dannz', 'Farrow', datetime.date(1985, 8, 23), 3),
#  ('Gilbert', 'Bruckman', datetime.date(1985, 8, 26), 3),
#  ('Sastry', 'Hasham', datetime.date(1985, 8, 27), 3),
#  ('Conrado', 'Brendel', datetime.date(1985, 8, 28), 3),
#  ('Otilia', 'Bernick', datetime.date(1985, 8, 29), 3),
#  ('Susanna', 'Figueira', datetime.date(1985, 8, 29), 3),
#  ('Halsur', 'Papadias', datetime.date(1985, 8, 29), 3),
#  ('Xiaoqiu', 'Speek', datetime.date(1985, 8, 29), 3),
#  ('Gilbert', 'Rajcani', datetime.date(1985, 8, 30), 3),
#  ('Georgi', 'Chartres', datetime.date(1985, 8, 30), 3),
#  ('Aris', 'Iwayama', datetime.date(1985, 8, 31), 3),
#  ('Marsja', 'Rabejac', datetime.date(1985, 8, 31), 3),
#  ('Kankanahalli', 'Honiden', datetime.date(1985, 9, 2), 3),
#  ('Insup', 'Gronowski', datetime.date(1985, 9, 2), 3),
#  ('Subhrajyoti', 'Monkewich', datetime.date(1985, 9, 2), 3),
#  ('Lijie', 'Landherr', datetime.date(1985, 9, 2), 3),
#  ('Manton', 'Kermarrec', datetime.date(1985, 9, 2), 3),
#  ('Mohamadou', 'Pappas', datetime.date(1985, 9, 2), 3),
#  ('Hideo', 'Busillo', datetime.date(1985, 9, 3), 3),
#  ('Guadalupe', 'Piancastelli', datetime.date(1985, 9, 3), 3),
#  ('Jianhua', 'Esteva', datetime.date(1985, 9, 3), 3),
#  ('Takahira', 'Hashii', datetime.date(1985, 9, 4), 3),
#  ('Wojceich', 'Peck', datetime.date(1985, 9, 4), 3),
#  ('Dekang', 'Rosar', datetime.date(1985, 9, 5), 3),
#  ('Kagan', 'Kalorkoti', datetime.date(1985, 9, 5), 3),
#  ('Fabrizio', 'Mundy', datetime.date(1985, 9, 6), 3),
#  ('Tianruo', 'Hasenauer', datetime.date(1985, 9, 7), 3),
#  ('Irena', 'Breugel', datetime.date(1985, 9, 7), 3),
#  ('Shiv', 'Hmelo', datetime.date(1985, 9, 9), 3),
#  ('Breannda', 'Fairtlough', datetime.date(1985, 9, 10), 3),
#  ('Youssef', 'Bashian', datetime.date(1985, 9, 10), 3),
#  ('Gill', 'Nittel', datetime.date(1985, 9, 11), 3),
#  ('Krisda', 'Krogh', datetime.date(1985, 9, 11), 3),
#  ('Bogdan', 'Perri', datetime.date(1985, 9, 12), 3),
#  ('Fai', 'Francisci', datetime.date(1985, 9, 12), 3),
#  ('Augustine', 'Gubsky', datetime.date(1985, 9, 12), 3),
#  ('Vidya', 'Rothe', datetime.date(1985, 9, 13), 3),
#  ('Parke', 'Schurmann', datetime.date(1985, 9, 13), 3),
#  ('Dayanand', 'Rosis', datetime.date(1985, 9, 13), 3),
#  ('Horward', 'Camarinopoulos', datetime.date(1985, 9, 13), 3),
#  ('Zejun', 'Oehlmann', datetime.date(1985, 9, 14), 3),
#  ('Martins', 'Lung', datetime.date(1985, 9, 14), 3),
#  ('Along', 'Miake', datetime.date(1985, 9, 15), 3),
#  ('Xiaoqiu', 'Steenbeek', datetime.date(1985, 9, 15), 3),
#  ('Greger', 'Qiwen', datetime.date(1985, 9, 15), 3),
#  ('Idoia', 'Hooghiemstra', datetime.date(1985, 9, 15), 3),
#  ('Jeanne', 'Salinas', datetime.date(1985, 9, 16), 3),
#  ('Shahar', 'Koyama', datetime.date(1985, 9, 17), 3),
#  ('Hsiangchu', 'Cappelletti', datetime.date(1985, 9, 17), 3),
#  ('Pramod', 'Oaver', datetime.date(1985, 9, 18), 3),
#  ('Vincent', 'Demian', datetime.date(1985, 9, 18), 3),
#  ('Zdislav', 'Shimshoni', datetime.date(1985, 9, 18), 3),
#  ('Persi', 'Morris', datetime.date(1985, 9, 20), 3),
#  ('Mayumi', 'Bharadwaj', datetime.date(1985, 9, 21), 3),
#  ('Anoosh', 'Harllee', datetime.date(1985, 9, 21), 3),
#  ('Tianruo', 'Piveteau', datetime.date(1985, 9, 21), 3),
#  ('Adamantios', 'Cronan', datetime.date(1985, 9, 21), 3),
#  ('Seongbae', 'Staudhammer', datetime.date(1985, 9, 22), 3),
#  ('Hinrich', 'Cappelletti', datetime.date(1985, 9, 22), 3),
#  ('Munehiro', 'Schmiedel', datetime.date(1985, 9, 22), 3),
#  ('Mona', 'Krychniak', datetime.date(1985, 9, 22), 3),
#  ('Tommaso', 'Sessa', datetime.date(1985, 9, 23), 3),
#  ('Xuedong', 'Solovay', datetime.date(1985, 9, 23), 3),
#  ('Alper', 'Perez', datetime.date(1985, 9, 23), 3),
#  ('Niclas', 'Provine', datetime.date(1985, 9, 24), 3),
#  ('Xinglin', 'Beetstra', datetime.date(1985, 9, 24), 3),
#  ('Make', 'Mitina', datetime.date(1985, 9, 25), 3),
#  ('Duro', 'Rissanen', datetime.date(1985, 9, 26), 3),
#  ('Prasadram', 'Smailagic', datetime.date(1985, 9, 26), 3),
#  ('Shirish', 'Pollock', datetime.date(1985, 9, 26), 3),
#  ('Sadok', 'Gerlach', datetime.date(1985, 9, 27), 3),
#  ('Sariel', 'Smeets', datetime.date(1985, 9, 28), 3),
#  ('Eishiro', 'Rouquie', datetime.date(1985, 9, 28), 3),
#  ('Ewing', 'Krohm', datetime.date(1985, 9, 28), 3),
#  ('Bodh', 'Aloisi', datetime.date(1985, 9, 28), 3),
#  ('Katsuyuki', 'Suermann', datetime.date(1985, 9, 28), 3),
#  ('Vasiliy', 'Tempesti', datetime.date(1985, 9, 29), 3),
#  ('Fay', 'Erev', datetime.date(1985, 9, 29), 3),
#  ('Tzu', 'Bennet', datetime.date(1985, 9, 29), 3),
#  ('Danco', 'Conte', datetime.date(1985, 9, 30), 3),
#  ('Ortrun', 'Lichtner', datetime.date(1985, 9, 30), 3),
#  ('Aleksander', 'Bahk', datetime.date(1985, 9, 30), 3),
#  ('Jingling', 'Buchter', datetime.date(1985, 9, 30), 3),
#  ('Behnaam', 'Schlenzig', datetime.date(1985, 10, 1), 3),
#  ('Srinidhi', 'Azulay', datetime.date(1985, 10, 1), 3),
#  ('Basem', 'Merel', datetime.date(1985, 10, 1), 3),
#  ('Vitaly', 'Peron', datetime.date(1985, 10, 1), 3),
#  ('Muneo', 'Schwartzburd', datetime.date(1985, 10, 2), 3),
#  ('Zissis', 'Ghazalie', datetime.date(1985, 10, 2), 3),
#  ('Uma', 'Kaiser', datetime.date(1985, 10, 2), 3),
#  ('Maris', 'Barbanera', datetime.date(1985, 10, 2), 3),
#  ('Mohd', 'Jullig', datetime.date(1985, 10, 2), 3),
#  ('Kazuyasu', 'Ramaiah', datetime.date(1985, 10, 2), 3),
#  ('Fen', 'Nyanchama', datetime.date(1985, 10, 3), 3),
#  ('Shuzo', 'Ruemmler', datetime.date(1985, 10, 3), 3),
#  ('Poorav', 'Yamaashi', datetime.date(1985, 10, 4), 3),
#  ('Krisda', 'Walstra', datetime.date(1985, 10, 4), 3),
#  ('Tadanori', 'Rassart', datetime.date(1985, 10, 5), 3),
#  ('Sanjai', 'Uehara', datetime.date(1985, 10, 5), 3),
#  ('Alenka', 'Oppitz', datetime.date(1985, 10, 5), 3),
#  ('Almudena', 'Genther', datetime.date(1985, 10, 5), 3),
#  ('Wanqing', 'Thambidurai', datetime.date(1985, 10, 5), 3),
#  ('Fabrizio', 'Quadeer', datetime.date(1985, 10, 6), 3),
#  ('Leif', 'Aumann', datetime.date(1985, 10, 7), 3),
#  ('Munehiko', 'Maccarone', datetime.date(1985, 10, 7), 3),
#  ('Rutger', 'Wielonsky', datetime.date(1985, 10, 7), 3),
#  ('Hein', 'Prenel', datetime.date(1985, 10, 7), 3),
#  ('Lihong', 'Benantar', datetime.date(1985, 10, 8), 3),
#  ('Rimli', 'Melton', datetime.date(1985, 10, 8), 3),
#  ('Naraig', 'Jansen', datetime.date(1985, 10, 9), 3),
#  ('Nevin', 'Mellouli', datetime.date(1985, 10, 9), 3),
#  ('Seongbin', 'Steenbeek', datetime.date(1985, 10, 9), 3),
#  ('Valeska', 'Aseltine', datetime.date(1985, 10, 9), 3),
#  ('Angus', 'Rando', datetime.date(1985, 10, 10), 3),
#  ('Parto', 'Kavraki', datetime.date(1985, 10, 10), 3),
#  ('Ferdinand', 'Ullian', datetime.date(1985, 10, 10), 3),
#  ('Arunachalam', 'Tiemann', datetime.date(1985, 10, 13), 3),
#  ('Guenter', 'Kalefeld', datetime.date(1985, 10, 13), 3),
#  ('Billie', 'Llado', datetime.date(1985, 10, 13), 3),
#  ('Erez', 'Lanteri', datetime.date(1985, 10, 13), 3),
#  ('Teruyuki', 'Ossenbruggen', datetime.date(1985, 10, 13), 3),
#  ('Djelloul', 'Hammerschmidt', datetime.date(1985, 10, 13), 3),
#  ('Flemming', 'Slaats', datetime.date(1985, 10, 14), 3),
#  ('Emdad', 'Cangellaris', datetime.date(1985, 10, 15), 3),
#  ('Clyde', 'Bahl', datetime.date(1985, 10, 16), 3),
#  ('Akhilish', 'Zweizig', datetime.date(1985, 10, 17), 3),
#  ('Alain', 'Bala', datetime.date(1985, 10, 18), 3),
#  ('Chaosheng', 'Masand', datetime.date(1985, 10, 19), 3),
#  ('Sasan', 'Farrel', datetime.date(1985, 10, 20), 3),
#  ('Munehiro', 'Jervis', datetime.date(1985, 10, 20), 3),
#  ('Limsoon', 'Wossner', datetime.date(1985, 10, 20), 3),
#  ('Remmert', 'Menhoudj', datetime.date(1985, 10, 20), 3),
#  ('Cheong', 'Nations', datetime.date(1985, 10, 21), 3),
#  ('Sanjai', 'Litzler', datetime.date(1985, 10, 21), 3),
#  ('Sanjit', 'Lorcy', datetime.date(1985, 10, 22), 3),
#  ('Gay', 'Improta', datetime.date(1985, 10, 24), 3),
#  ('Fusako', 'Christianini', datetime.date(1985, 10, 24), 3),
#  ('Gaetan', 'Gimarc', datetime.date(1985, 10, 24), 3),
#  ('Haldun', 'Liedekerke', datetime.date(1985, 10, 25), 3),
#  ('Yechiam', 'Kaiserswerth', datetime.date(1985, 10, 25), 3),
#  ('Fen', 'Swiler', datetime.date(1985, 10, 26), 3),
#  ('Huai', 'Lally', datetime.date(1985, 10, 26), 3),
#  ('Branimir', 'Benaini', datetime.date(1985, 10, 27), 3),
#  ('Fumiya', 'Fordan', datetime.date(1985, 10, 28), 3),
#  ('Salvador', 'Shinomoto', datetime.date(1985, 10, 28), 3),
#  ('DAIDA', 'Rusterholz', datetime.date(1985, 10, 28), 3),
#  ('Susuma', 'Angel', datetime.date(1985, 10, 29), 3),
#  ('Sverrir', 'Bage', datetime.date(1985, 10, 29), 3),
#  ('Tristan', 'Uludag', datetime.date(1985, 10, 29), 3),
#  ('Taiji', 'Melton', datetime.date(1985, 10, 29), 3),
#  ('Babette', 'Vesna', datetime.date(1985, 10, 30), 3),
#  ('Saeed', 'Dengi', datetime.date(1985, 10, 30), 3),
#  ('Mokhtar', 'Falby', datetime.date(1985, 10, 31), 3),
#  ('Vidar', 'Deyuan', datetime.date(1985, 10, 31), 3),
#  ('Jordanka', 'Lunt', datetime.date(1985, 11, 1), 3),
#  ('Jeanne', 'Litzkow', datetime.date(1985, 11, 3), 3),
#  ('Kristen', 'Stentiford', datetime.date(1985, 11, 3), 3),
#  ('Toshiki', 'Sinicrope', datetime.date(1985, 11, 3), 3),
#  ('Olivera', 'Apsitis', datetime.date(1985, 11, 3), 3),
#  ('Remko', 'Budinsky', datetime.date(1985, 11, 3), 3),
#  ('Kristina', 'Schmiedel', datetime.date(1985, 11, 4), 3),
#  ('Krassimir', 'Suri', datetime.date(1985, 11, 4), 3),
#  ('Etsuo', 'Negoita', datetime.date(1985, 11, 4), 3),
#  ('Serge', 'Levergood', datetime.date(1985, 11, 5), 3),
#  ('Cullen', 'Fiutem', datetime.date(1985, 11, 5), 3),
#  ('Woody', 'Mansanne', datetime.date(1985, 11, 5), 3),
#  ('Remmert', 'Bale', datetime.date(1985, 11, 5), 3),
#  ('Mani', 'Matzke', datetime.date(1985, 11, 6), 3),
#  ('Laurentiu', 'Raney', datetime.date(1985, 11, 6), 3),
#  ('Vincent', 'Stellhorn', datetime.date(1985, 11, 6), 3),
#  ('Zejun', 'Schwabacher', datetime.date(1985, 11, 6), 3),
#  ('Brewster', 'Rodiger', datetime.date(1985, 11, 7), 3),
#  ('Alassane', 'Hiltgen', datetime.date(1985, 11, 7), 3),
#  ('Dinkar', 'Mitzlaff', datetime.date(1985, 11, 7), 3),
#  ('Uzi', 'Furudate', datetime.date(1985, 11, 7), 3),
#  ('Alper', 'Swist', datetime.date(1985, 11, 8), 3),
#  ('Maha', 'Brodie', datetime.date(1985, 11, 9), 3),
#  ('Hideyuki', 'Bratsberg', datetime.date(1985, 11, 9), 3),
#  ('Piyush', 'Beilner', datetime.date(1985, 11, 10), 3),
#  ('Chrisa', 'Oberman', datetime.date(1985, 11, 11), 3),
#  ('Takahira', 'Fandrianto', datetime.date(1985, 11, 12), 3),
#  ('Guther', 'Gornas', datetime.date(1985, 11, 12), 3),
#  ('Leen', 'Kawashima', datetime.date(1985, 11, 12), 3),
#  ('Jacopo', 'Sichman', datetime.date(1985, 11, 13), 3),
#  ('Owen', 'Huhdanpaa', datetime.date(1985, 11, 13), 3),
#  ('Kaijung', 'Keustermans', datetime.date(1985, 11, 13), 3),
#  ('Faiza', 'Heuser', datetime.date(1985, 11, 13), 3),
#  ('Margo', 'Plumb', datetime.date(1985, 11, 14), 3),
#  ('Mototsugu', 'Versino', datetime.date(1985, 11, 14), 3),
#  ('Guozhong', 'Peot', datetime.date(1985, 11, 15), 3),
#  ('Zongyan', 'Merey', datetime.date(1985, 11, 15), 3),
#  ('Yakkov', 'Hiraishi', datetime.date(1985, 11, 15), 3),
#  ('Xuejun', 'Warwick', datetime.date(1985, 11, 16), 3),
#  ('Aamer', 'Bahr', datetime.date(1985, 11, 16), 3),
#  ('Arvin', 'Coney', datetime.date(1985, 11, 16), 3),
#  ('Pranay', 'Peres', datetime.date(1985, 11, 16), 3),
#  ('Genta', 'Stellhorn', datetime.date(1985, 11, 16), 3),
#  ('Lidong', 'Honglei', datetime.date(1985, 11, 17), 3),
#  ('Honglan', 'Underwood', datetime.date(1985, 11, 17), 3),
#  ('Subir', 'Peha', datetime.date(1985, 11, 17), 3),
#  ('Tonny', 'Murillo', datetime.date(1985, 11, 17), 3),
#  ('Duro', 'Trumbly', datetime.date(1985, 11, 17), 3),
#  ('Yurij', 'Thiran', datetime.date(1985, 11, 18), 3),
#  ('Sachar', 'Emiris', datetime.date(1985, 11, 18), 3),
#  ('Narain', 'Falster', datetime.date(1985, 11, 18), 3),
#  ('Zeydy', 'Schusler', datetime.date(1985, 11, 19), 3),
#  ('Mario', 'Pearson', datetime.date(1985, 11, 20), 3),
#  ('Ibibia', 'Perez', datetime.date(1985, 11, 20), 3),
#  ('Tremaine', 'Straney', datetime.date(1985, 11, 21), 3),
#  ('Bedrich', 'Markovitch', datetime.date(1985, 11, 22), 3),
#  ('Rosine', 'Cools', datetime.date(1985, 11, 22), 3),
#  ('Nectarios', 'Doering', datetime.date(1985, 11, 22), 3),
#  ('Huan', 'Iwayama', datetime.date(1985, 11, 22), 3),
#  ('Masasuke', 'Biran', datetime.date(1985, 11, 24), 3),
#  ('Tze', 'Gyimothy', datetime.date(1985, 11, 25), 3),
#  ('Saeed', 'Encarnacion', datetime.date(1985, 11, 26), 3),
#  ('Aemilian', 'Hoppenstand', datetime.date(1985, 11, 27), 3),
#  ('Basant', 'Buchter', datetime.date(1985, 11, 27), 3),
#  ('Shan', 'Casley', datetime.date(1985, 11, 27), 3),
#  ('Shin', 'Itzigehl', datetime.date(1985, 11, 27), 3),
#  ('Sadun', 'Zschoche', datetime.date(1985, 11, 28), 3),
#  ('Kazunori', 'Gaughan', datetime.date(1985, 11, 28), 3),
#  ('Barun', 'Gist', datetime.date(1985, 11, 29), 3),
#  ('Yannis', 'Lamma', datetime.date(1985, 11, 30), 3),
#  ('Divine', 'Benaini', datetime.date(1985, 12, 1), 3),
#  ('Rosalie', 'Beutelspacher', datetime.date(1985, 12, 1), 3),
#  ('Shigehito', 'Marchesini', datetime.date(1985, 12, 1), 3),
#  ('Sandeepan', 'Openshaw', datetime.date(1985, 12, 1), 3),
#  ('Yonghong', 'Giveon', datetime.date(1985, 12, 2), 3),
#  ('Radhakrishnan', 'Lamparter', datetime.date(1985, 12, 2), 3),
#  ('Subbu', 'Assaf', datetime.date(1985, 12, 3), 3),
#  ('Jovan', 'Rotem', datetime.date(1985, 12, 3), 3),
#  ('Ger', 'Ressouche', datetime.date(1985, 12, 3), 3),
#  ('Gaurav', 'Pettit', datetime.date(1985, 12, 4), 3),
#  ('Younwoo', 'Chepyzhov', datetime.date(1985, 12, 4), 3),
#  ('Yuriy', 'Wilharm', datetime.date(1985, 12, 5), 3),
#  ('Jessie', 'Akaboshi', datetime.date(1985, 12, 5), 3),
#  ('Leif', 'Gelosh', datetime.date(1985, 12, 6), 3),
#  ('Inderjeet', 'Nations', datetime.date(1985, 12, 6), 3),
#  ('Danny', 'Sooriamurthi', datetime.date(1985, 12, 7), 3),
#  ('Shushma', 'Hofmeyr', datetime.date(1985, 12, 7), 3),
#  ('Jeane', 'Demian', datetime.date(1985, 12, 8), 3),
#  ('Idoia', 'Gurbaxani', datetime.date(1985, 12, 8), 3),
#  ('Samphel', 'Georg', datetime.date(1985, 12, 9), 3),
#  ('Ziva', 'Perri', datetime.date(1985, 12, 9), 3),
#  ('Arvin', 'Bain', datetime.date(1985, 12, 10), 3),
#  ('Arnd', 'Strehl', datetime.date(1985, 12, 10), 3),
#  ('Emran', 'Munch', datetime.date(1985, 12, 10), 3),
#  ('Djelloul', 'Lyonns', datetime.date(1985, 12, 11), 3),
#  ('Van', 'Brattka', datetime.date(1985, 12, 11), 3),
#  ('Mona', 'Gustavson', datetime.date(1985, 12, 11), 3),
#  ('Danil', 'Hockney', datetime.date(1985, 12, 12), 3),
#  ('Moti', 'Milicic', datetime.date(1985, 12, 12), 3),
#  ('Jordanka', 'Tiemann', datetime.date(1985, 12, 12), 3),
#  ('Hitomi', 'Magalhaes', datetime.date(1985, 12, 12), 3),
#  ('Kinh', 'Kusakabe', datetime.date(1985, 12, 12), 3),
#  ('Mana', 'Begiun', datetime.date(1985, 12, 13), 3),
#  ('Peternela', 'Range', datetime.date(1985, 12, 13), 3),
#  ('Xiaoshan', 'Bondorf', datetime.date(1985, 12, 13), 3),
#  ('Moon', 'Akaboshi', datetime.date(1985, 12, 14), 3),
#  ('Rance', 'Laventhal', datetime.date(1985, 12, 14), 3),
#  ('Tokuyasu', 'Binkley', datetime.date(1985, 12, 15), 3),
#  ('Lubomir', 'Ghandeharizadeh', datetime.date(1985, 12, 15), 3),
#  ('Mostafa', 'Cullers', datetime.date(1985, 12, 15), 3),
#  ('Ekawit', 'Badr', datetime.date(1985, 12, 15), 3),
#  ('Xiaoshan', 'Lemarechal', datetime.date(1985, 12, 16), 3),
#  ('Xiahua', 'Hiraishi', datetime.date(1985, 12, 16), 3),
#  ('Chaoyi', 'Preusig', datetime.date(1985, 12, 16), 3),
#  ('Geoffrey', 'Spell', datetime.date(1985, 12, 16), 3),
#  ('Salvador', 'Bednarek', datetime.date(1985, 12, 17), 3),
#  ('Heekeun', 'Bolotov', datetime.date(1985, 12, 17), 3),
#  ('Eberhardt', 'Detkin', datetime.date(1985, 12, 18), 3),
#  ('Rosita', 'Bellone', datetime.date(1985, 12, 18), 3),
#  ('Ewing', 'Xiaoshan', datetime.date(1985, 12, 18), 3),
#  ('Barton', 'Nyrup', datetime.date(1985, 12, 19), 3),
#  ('Ibibia', 'Makrucki', datetime.date(1985, 12, 20), 3),
#  ('Seongbin', 'Picaronny', datetime.date(1985, 12, 20), 3),
#  ('Miquel', 'Farrel', datetime.date(1985, 12, 21), 3),
#  ('Chenye', 'Aloisi', datetime.date(1985, 12, 21), 3),
#  ('Volkmar', 'Lodder', datetime.date(1985, 12, 21), 3),
#  ('Irena', 'Hoppenstand', datetime.date(1985, 12, 22), 3),
#  ('Bedrich', 'Driscoll', datetime.date(1985, 12, 24), 3),
#  ('Gurbir', 'Champarnaud', datetime.date(1985, 12, 24), 3),
#  ('Honesty', 'Denti', datetime.date(1985, 12, 24), 3),
#  ('Aluzio', 'Desikan', datetime.date(1985, 12, 24), 3),
#  ('Becky', 'Gargeya', datetime.date(1985, 12, 24), 3),
#  ('Arra', 'Mamelak', datetime.date(1985, 12, 25), 3),
#  ('Sachio', 'Suri', datetime.date(1985, 12, 25), 3),
#  ('Chriss', 'Puppo', datetime.date(1985, 12, 26), 3),
#  ('Sashi', 'Dredge', datetime.date(1985, 12, 26), 3),
#  ('Stafford', 'Bennet', datetime.date(1985, 12, 26), 3),
#  ('Baruch', 'Comte', datetime.date(1985, 12, 27), 3),
#  ('Takahito', 'Minakawa', datetime.date(1985, 12, 28), 3),
#  ('Kolar', 'Giveon', datetime.date(1985, 12, 28), 3),
#  ('Sachin', 'Lupu', datetime.date(1985, 12, 30), 3),
#  ('Pintsang', 'Heyers', datetime.date(1985, 12, 30), 3),
#  ('Geoffrey', 'Kandlur', datetime.date(1985, 12, 30), 3),
#  ('Xiaobin', 'Cyne', datetime.date(1985, 12, 30), 3),
#  ('Genevieve', 'Codenie', datetime.date(1985, 12, 31), 3),
#  ('Munehiko', 'Masaki', datetime.date(1986, 1, 1), 3),
#  ('Kazunori', 'Meriste', datetime.date(1986, 1, 1), 3),
#  ('Mohammad', 'Ghemri', datetime.date(1986, 1, 2), 3),
#  ('Raimond', 'Mitina', datetime.date(1986, 1, 2), 3),
#  ('Jinya', 'Marrakchi', datetime.date(1986, 1, 3), 3),
#  ('Sergi', 'Jeansoulin', datetime.date(1986, 1, 3), 3),
#  ('Nishit', 'Heiserman', datetime.date(1986, 1, 3), 3),
#  ('Alain', 'Griswold', datetime.date(1986, 1, 3), 3),
#  ('Georg', 'Munoz', datetime.date(1986, 1, 3), 3),
#  ('Masasuke', 'Tetzlaff', datetime.date(1986, 1, 4), 3),
#  ('Lubomir', 'Pesch', datetime.date(1986, 1, 7), 3),
#  ('Moti', 'Crelier', datetime.date(1986, 1, 7), 3),
#  ('Trygve', 'Malabarba', datetime.date(1986, 1, 8), 3),
#  ('Geoffrey', 'Nyrup', datetime.date(1986, 1, 8), 3),
#  ('Yoshimitsu', 'Taubenfeld', datetime.date(1986, 1, 9), 3),
#  ('Ziva', 'Beilner', datetime.date(1986, 1, 9), 3),
#  ('Sasan', 'Ouhyoung', datetime.date(1986, 1, 9), 3),
#  ('Mandell', 'Covnot', datetime.date(1986, 1, 10), 3),
#  ('Gretta', 'Czap', datetime.date(1986, 1, 11), 3),
#  ('Leszek', 'Litzler', datetime.date(1986, 1, 12), 3),
#  ('Ashish', 'Rikino', datetime.date(1986, 1, 12), 3),
#  ('Khalid', 'Schlenzig', datetime.date(1986, 1, 12), 3),
#  ('Barna', 'Picco', datetime.date(1986, 1, 13), 3),
#  ('Terresa', 'Weedon', datetime.date(1986, 1, 13), 3),
#  ('Masoud', 'Perz', datetime.date(1986, 1, 13), 3),
#  ('Gay', 'Bellmore', datetime.date(1986, 1, 14), 3),
#  ('Mizuhito', 'Eiron', datetime.date(1986, 1, 14), 3),
#  ('Rosella', 'Peak', datetime.date(1986, 1, 15), 3),
#  ('Nechama', 'Gaughan', datetime.date(1986, 1, 16), 3),
#  ('Yuriy', 'Nitta', datetime.date(1986, 1, 16), 3),
#  ('Gad', 'Merel', datetime.date(1986, 1, 17), 3),
#  ('Moss', 'Vakili', datetime.date(1986, 1, 17), 3),
#  ('Irene', 'Laurillard', datetime.date(1986, 1, 18), 3),
#  ('Weiyi', 'Parveen', datetime.date(1986, 1, 18), 3),
#  ('Jiann', 'Tagansky', datetime.date(1986, 1, 18), 3),
#  ('Claude', 'Verhaegen', datetime.date(1986, 1, 18), 3),
#  ('Tetsushi', 'Mamelak', datetime.date(1986, 1, 19), 3),
#  ('Chenxi', 'Beidas', datetime.date(1986, 1, 19), 3),
#  ('Saeko', 'Montresor', datetime.date(1986, 1, 19), 3),
#  ('Tsuneo', 'Rebaine', datetime.date(1986, 1, 20), 3),
#  ('Tetsushi', 'Riexinger', datetime.date(1986, 1, 21), 3),
#  ('Eckart', 'Chandrasekhar', datetime.date(1986, 1, 21), 3),
#  ('Muneo', 'Businaro', datetime.date(1986, 1, 22), 3),
#  ('Luerbio', 'Gips', datetime.date(1986, 1, 22), 3),
#  ('Perla', 'Highland', datetime.date(1986, 1, 22), 3),
#  ('Stabislas', 'Rosin', datetime.date(1986, 1, 23), 3),
#  ('Dayanand', 'Bade', datetime.date(1986, 1, 24), 3),
#  ('Hidefumi', 'Rajcani', datetime.date(1986, 1, 25), 3),
#  ('Shridhar', 'Zeleznik', datetime.date(1986, 1, 25), 3),
#  ('Sanjiv', 'Lagarias', datetime.date(1986, 1, 26), 3),
#  ('Karoline', 'Broomell', datetime.date(1986, 1, 26), 3),
#  ('Zongyan', 'Demos', datetime.date(1986, 1, 26), 3),
#  ('Mechthild', 'Alpin', datetime.date(1986, 1, 26), 3),
#  ('Abdelwaheb', 'Randt', datetime.date(1986, 1, 26), 3),
#  ('Sachar', 'Molberg', datetime.date(1986, 1, 26), 3),
#  ('Arie', 'Cronan', datetime.date(1986, 1, 26), 3),
#  ('Christ', 'Ozeki', datetime.date(1986, 1, 28), 3),
#  ('Randy', 'Eickenmeyer', datetime.date(1986, 1, 29), 3),
#  ('Marc', 'Emden', datetime.date(1986, 1, 30), 3),
#  ('Mokhtar', 'Zultner', datetime.date(1986, 1, 30), 3),
#  ('Houman', 'Gruenwald', datetime.date(1986, 1, 30), 3),
#  ('Jiann', 'Pena', datetime.date(1986, 1, 31), 3),
#  ('Goncalo', 'Stenning', datetime.date(1986, 2, 2), 3),
#  ('Akhilish', 'Olano', datetime.date(1986, 2, 3), 3),
#  ('Xiaopeng', 'Cmelik', datetime.date(1986, 2, 3), 3),
#  ('Adas', 'Vieri', datetime.date(1986, 2, 4), 3),
#  ('Danel', 'Baezner', datetime.date(1986, 2, 5), 3),
#  ('Utz', 'Benzaken', datetime.date(1986, 2, 6), 3),
#  ('Kokou', 'Heuser', datetime.date(1986, 2, 6), 3),
#  ('Macha', 'Glowinski', datetime.date(1986, 2, 6), 3),
#  ('Fumitake', 'Rohrbach', datetime.date(1986, 2, 6), 3),
#  ('Piyawadee', 'Picci', datetime.date(1986, 2, 7), 3),
#  ('Duro', 'Msuda', datetime.date(1986, 2, 7), 3),
#  ('Susumu', 'Oehlmann', datetime.date(1986, 2, 7), 3),
#  ('Salvador', 'Thummel', datetime.date(1986, 2, 7), 3),
#  ('Aluzio', 'Otillio', datetime.date(1986, 2, 9), 3),
#  ('Sanjeeva', 'Rande', datetime.date(1986, 2, 10), 3),
#  ('Szabolcs', 'Marzano', datetime.date(1986, 2, 10), 3),
#  ('Moon', 'Rotem', datetime.date(1986, 2, 11), 3),
#  ('Syozo', 'Birjandi', datetime.date(1986, 2, 13), 3),
#  ('Weidon', 'Tanemo', datetime.date(1986, 2, 13), 3),
#  ('Vitali', 'Zwicker', datetime.date(1986, 2, 13), 3),
#  ('Oddvar', 'Bottner', datetime.date(1986, 2, 13), 3),
#  ('Bojan', 'Weiland', datetime.date(1986, 2, 14), 3),
#  ('Satosi', 'Gunderson', datetime.date(1986, 2, 14), 3),
#  ('Rosella', 'Foong', datetime.date(1986, 2, 15), 3),
#  ('Shahab', 'Assaf', datetime.date(1986, 2, 15), 3),
#  ('Abdulla', 'Granlund', datetime.date(1986, 2, 15), 3),
#  ('Willard', 'Baar', datetime.date(1986, 2, 16), 3),
#  ('Akemi', 'Biros', datetime.date(1986, 2, 16), 3),
#  ('Frederique', 'Prenel', datetime.date(1986, 2, 16), 3),
#  ('Monique', 'Nourani', datetime.date(1986, 2, 17), 3),
#  ('Vivian', 'Holburn', datetime.date(1986, 2, 17), 3),
#  ('Yunming', 'Lenart', datetime.date(1986, 2, 17), 3),
#  ('Constantino', 'Narlikar', datetime.date(1986, 2, 17), 3),
#  ('Mingdong', 'Czaja', datetime.date(1986, 2, 18), 3),
#  ('Chiradeep', 'Simmen', datetime.date(1986, 2, 18), 3),
#  ('Olivera', 'Langford', datetime.date(1986, 2, 19), 3),
#  ('Aimee', 'Provine', datetime.date(1986, 2, 19), 3),
#  ('Boguslaw', 'Soicher', datetime.date(1986, 2, 19), 3),
#  ('Rosita', 'Makinen', datetime.date(1986, 2, 20), 3),
#  ('Eckart', 'Asmuth', datetime.date(1986, 2, 20), 3),
#  ('Ingemar', 'Birnbaum', datetime.date(1986, 2, 21), 3),
#  ('Kamran', 'Rahier', datetime.date(1986, 2, 21), 3),
#  ('Sham', 'Buescher', datetime.date(1986, 2, 21), 3),
#  ('Sanjay', 'Giveon', datetime.date(1986, 2, 22), 3),
#  ('Junichi', 'Sluis', datetime.date(1986, 2, 23), 3),
#  ('Cheong', 'Steenbeek', datetime.date(1986, 2, 23), 3),
#  ('Toney', 'Birdsall', datetime.date(1986, 2, 24), 3),
#  ('Jingling', 'Shackel', datetime.date(1986, 2, 24), 3),
#  ('Jamaludin', 'Morris', datetime.date(1986, 2, 25), 3),
#  ('Venkatesan', 'Vigier', datetime.date(1986, 2, 25), 3),
#  ('Odysseas', 'Mateescu', datetime.date(1986, 2, 25), 3),
#  ('Kwee', 'Schusler', datetime.date(1986, 2, 26), 3),
#  ('Palash', 'Kleiser', datetime.date(1986, 2, 26), 3),
#  ('Shir', 'Kusalik', datetime.date(1986, 2, 26), 3),
#  ('Prodip', 'Varker', datetime.date(1986, 2, 28), 3),
#  ('Halsur', 'Lorcy', datetime.date(1986, 3, 1), 3),
#  ('Tru', 'Stanfel', datetime.date(1986, 3, 1), 3),
#  ('Lalit', 'Passino', datetime.date(1986, 3, 2), 3),
#  ('Harngdar', 'Moehrke', datetime.date(1986, 3, 2), 3),
#  ('Anneli', 'Basart', datetime.date(1986, 3, 2), 3),
#  ('Godehard', 'Parhami', datetime.date(1986, 3, 2), 3),
#  ('Moie', 'Preusig', datetime.date(1986, 3, 2), 3),
#  ('Charmane', 'Schiettecatte', datetime.date(1986, 3, 2), 3),
#  ('Itzchak', 'Magliocco', datetime.date(1986, 3, 3), 3),
#  ('Heng', 'Lortz', datetime.date(1986, 3, 3), 3),
#  ('Udo', 'Servi', datetime.date(1986, 3, 4), 3),
#  ('Fumiko', 'Angelopoulos', datetime.date(1986, 3, 5), 3),
#  ('Udo', 'Hofman', datetime.date(1986, 3, 5), 3),
#  ('Babette', 'Shackell', datetime.date(1986, 3, 5), 3),
#  ('Holgard', 'Zastre', datetime.date(1986, 3, 6), 3),
#  ('Etsuo', 'Kinley', datetime.date(1986, 3, 6), 3),
#  ('Gunilla', 'Pileggi', datetime.date(1986, 3, 7), 3),
#  ('Xuedong', 'Lunn', datetime.date(1986, 3, 7), 3),
#  ('Huican', 'Feldmann', datetime.date(1986, 3, 7), 3),
#  ('Gina', 'Pepe', datetime.date(1986, 3, 7), 3),
#  ('Aloke', 'Luiz', datetime.date(1986, 3, 7), 3),
#  ('Koldo', 'Weisert', datetime.date(1986, 3, 8), 3),
#  ('Ulises', 'Schwartzbauer', datetime.date(1986, 3, 9), 3),
#  ('Rosli', 'Cherinka', datetime.date(1986, 3, 10), 3),
#  ('Rimli', 'Ouhyoung', datetime.date(1986, 3, 10), 3),
#  ('Sugwoo', 'Sluis', datetime.date(1986, 3, 10), 3),
#  ('Kiyokazu', 'Makinen', datetime.date(1986, 3, 11), 3),
#  ('Mabry', 'Maksimenko', datetime.date(1986, 3, 11), 3),
#  ('Cheong', 'Kambil', datetime.date(1986, 3, 12), 3),
#  ('Srinidhi', 'Oxman', datetime.date(1986, 3, 12), 3),
#  ('Brewster', 'Cannane', datetime.date(1986, 3, 12), 3),
#  ('Mihalis', 'Setlzner', datetime.date(1986, 3, 13), 3),
#  ('Petter', 'Klassen', datetime.date(1986, 3, 13), 3),
#  ('Rayond', 'Edelhoff', datetime.date(1986, 3, 13), 3),
#  ('Reinhold', 'Dalton', datetime.date(1986, 3, 13), 3),
#  ('Heping', 'Silva', datetime.date(1986, 3, 14), 3),
#  ('Maren', 'Gimbel', datetime.date(1986, 3, 14), 3),
#  ('Pasqua', 'Worfolk', datetime.date(1986, 3, 15), 3),
#  ('Xudong', 'Furedi', datetime.date(1986, 3, 15), 3),
#  ('Sergi', 'Polupanov', datetime.date(1986, 3, 16), 3),
#  ('True', 'Heiserman', datetime.date(1986, 3, 16), 3),
#  ('Takanari', 'Schwartzburd', datetime.date(1986, 3, 16), 3),
#  ('Parto', 'Schmezko', datetime.date(1986, 3, 17), 3),
#  ('Shalesh', 'Marzano', datetime.date(1986, 3, 18), 3),
#  ('Feipei', 'Hofman', datetime.date(1986, 3, 18), 3),
#  ('Otilia', 'Nanard', datetime.date(1986, 3, 18), 3),
#  ('Ranga', 'Lichtman', datetime.date(1986, 3, 19), 3),
#  ('Atreye', 'Haldar', datetime.date(1986, 3, 20), 3),
#  ('Zengping', 'Nourani', datetime.date(1986, 3, 20), 3),
#  ('Lijie', 'Kadhim', datetime.date(1986, 3, 20), 3),
#  ('Zsolt', 'Facello', datetime.date(1986, 3, 21), 3),
#  ('Pantung', 'Turnbull', datetime.date(1986, 3, 21), 3),
#  ('Mart', 'Brandsma', datetime.date(1986, 3, 21), 3),
#  ('Fen', 'Parfitt', datetime.date(1986, 3, 21), 3),
#  ('Moriyoshi', 'Bael', datetime.date(1986, 3, 22), 3),
#  ('Ger', 'Delgrande', datetime.date(1986, 3, 22), 3),
#  ('Stamatina', 'Lammel', datetime.date(1986, 3, 22), 3),
#  ('Shridhar', 'Chleq', datetime.date(1986, 3, 22), 3),
#  ('Shounak', 'Hemaspaandra', datetime.date(1986, 3, 22), 3),
#  ('Mart', 'Conia', datetime.date(1986, 3, 22), 3),
#  ('Hauke', 'Tomescu', datetime.date(1986, 3, 23), 3),
#  ('Fox', 'Begiun', datetime.date(1986, 3, 23), 3),
#  ('Sibyl', 'Joslin', datetime.date(1986, 3, 23), 3),
#  ('Prodip', 'Vingron', datetime.date(1986, 3, 24), 3),
#  ('Lobel', 'Fiutem', datetime.date(1986, 3, 24), 3),
#  ('Ulf', 'Serot', datetime.date(1986, 3, 24), 3),
#  ('Kitty', 'Ushiama', datetime.date(1986, 3, 24), 3),
#  ('Mang', 'Marchesini', datetime.date(1986, 3, 25), 3),
#  ('Chinya', 'Tsunoo', datetime.date(1986, 3, 25), 3),
#  ('Jianhao', 'Fandrianto', datetime.date(1986, 3, 25), 3),
#  ('Bouchung', 'Rosis', datetime.date(1986, 3, 26), 3),
#  ('Jeane', 'Bratten', datetime.date(1986, 3, 27), 3),
#  ('Kerhong', 'Angot', datetime.date(1986, 3, 27), 3),
#  ('Divier', 'Rebaine', datetime.date(1986, 3, 27), 3),
#  ('Xiaopeng', 'Schurmann', datetime.date(1986, 3, 27), 3),
#  ('Bilhanan', 'Wrigley', datetime.date(1986, 3, 28), 3),
#  ('Manton', 'Raoux', datetime.date(1986, 3, 30), 3),
#  ('Florian', 'Journel', datetime.date(1986, 3, 31), 3),
#  ('Pascal', 'Litecky', datetime.date(1986, 3, 31), 3),
#  ('Gino', 'Fandrianto', datetime.date(1986, 4, 1), 3),
#  ('Mohammad', 'Kampfer', datetime.date(1986, 4, 2), 3),
#  ('Giap', 'Salverda', datetime.date(1986, 4, 2), 3),
#  ('Gio', 'Georg', datetime.date(1986, 4, 3), 3),
#  ('Mikhail', 'Gecsel', datetime.date(1986, 4, 4), 3),
#  ('Shunichi', 'Versino', datetime.date(1986, 4, 4), 3),
#  ('Hidde', 'Schrift', datetime.date(1986, 4, 5), 3),
#  ('Odysseas', 'Stafford', datetime.date(1986, 4, 6), 3),
#  ('Dines', 'Pintelas', datetime.date(1986, 4, 7), 3),
#  ('Poorav', 'Cronan', datetime.date(1986, 4, 8), 3),
#  ('Shaunak', 'Solares', datetime.date(1986, 4, 8), 3),
#  ('Mohammad', 'Denos', datetime.date(1986, 4, 9), 3),
#  ('Claude', 'Stroustrup', datetime.date(1986, 4, 10), 3),
#  ('Steen', 'Nyanchama', datetime.date(1986, 4, 11), 3),
#  ('Alper', 'Schauser', datetime.date(1986, 4, 11), 3),
#  ...]

# %% [markdown]
# ### Find all employees who have salaries above average.

# %%
# %%sql
#
# select first_name, last_name, salary
# from employees natural join salaries
# where now() < to_date and salary > (select avg(salary) from salaries where now() < to_date )
# limit 10;
# Out:
# 10 rows affected.
# [('Kaijung', 'Yeung', 80115),
#  ('Brewster', 'Birdsall', 105918),
#  ('Conrado', 'Riexinger', 79049),
#  ('Magy', 'Ligten', 89759),
#  ('Garnet', 'Highland', 116711),
#  ('Mayuri', 'Strooper', 82313),
#  ('Boguslaw', 'Cardazo', 75904),
#  ('Huican', 'Muhling', 77293),
#  ('Lillian', 'Godskesen', 76663),
#  ('Kenroku', 'Tetzlaff', 74151)]

# %% [markdown]
# ## Super Bonus Query
#
# ### Find all employees who have salaries above average for their department -- Not for the faint of heart!!

# %% [markdown]
# First lets figure out the query to calculate the average salary for a dept_no

# %%
# %%sql
#
# select dept_no, avg(salary)
# from dept_emp natural join employees join salaries on employees.emp_no = salaries.emp_no
# group by dept_no
# Out:
# 9 rows affected.
# [('d006', Decimal('57251.271913415990')),
#  ('d007', Decimal('80667.605755337693')),
#  ('d003', Decimal('55574.879369695531')),
#  ('d001', Decimal('71913.200004191532')),
#  ('d004', Decimal('59605.482461651448')),
#  ('d002', Decimal('70489.364896996098')),
#  ('d008', Decimal('59665.181701268599')),
#  ('d005', Decimal('59478.901162431823')),
#  ('d009', Decimal('58770.366479762480'))]

# %%
# %%sql
#
# select dept_name, first_name, last_name, salary
# from (departments natural join dept_emp natural join employees join
#     (select emp_no, salary from salaries where now() < to_date) as bar
#         on employees.emp_no = bar.emp_no) as foo
# where  salary > (select avg from
#                    (select dept_no, avg(salary)
#                     from dept_emp natural join employees join salaries on employees.emp_no = salaries.emp_no
#                     where foo.dept_no = dept_no and now() < salaries.to_date
#                     group by dept_no) x )
# limit 10
# Out:
# 10 rows affected.
# [('Development', 'Georgi', 'Facello', 88958),
#  ('Production', 'Chirstian', 'Koblick', 74057),
#  ('Human Resources', 'Kyoichi', 'Maliniak', 94692),
#  ('Research', 'Tzvetan', 'Zielinski', 88070),
#  ('Quality Management', 'Sumant', 'Peac', 94409),
#  ('Production', 'Duangkaew', 'Piveteau', 80324),
#  ('Quality Management', 'Duangkaew', 'Piveteau', 80324),
#  ('Human Resources', 'Eberhardt', 'Terkki', 68901),
#  ('Marketing', 'Cristinel', 'Bouloucos', 99651),
#  ('Production', 'Kazuhide', 'Peha', 84672)]

# %% [markdown]
# Notice the foo.dept_no = dept_no in the nested query in the where clause.  This is called a nested correlated query.  Tricky, and they are usually pretty cpu intensive as the inner query must be run for each row of the outer.
